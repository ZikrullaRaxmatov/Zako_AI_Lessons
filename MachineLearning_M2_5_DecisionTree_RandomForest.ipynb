# %% [markdown]
# <a href="https://colab.research.google.com/github/ZikrullaRaxmatov/Zako_AI_Lessons/blob/main/MachineLearning_M2_5_DecisionTree_RandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Logo_bg_insensitve.png](data:image/png;base64,...)

# %% [markdown]
# # Decision Tree & Random Forest

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Importing libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, classification_report, accuracy_score

import pandas as pd

# %%
# Loading a dataset
data = pd.read_csv('./prostate_cancer.txt')
data
# Out:
#     id    lcavol   lweight  age      lbph  svi       lcp  gleason  pgg45      lpsa train
# 0    1 -0.579818  2.769459   50 -1.386294    0 -1.386294        6      0 -0.430783     T
# 1    2 -0.994252  3.319626   58 -1.386294    0 -1.386294        6      0 -0.162519     T
# 2    3 -0.510826  2.691243   74 -1.386294    0 -1.386294        7     20 -0.162519     T
# 3    4 -1.203973  3.282789   58 -1.386294    0 -1.386294        6      0 -0.162519     T
# 4    5  0.751416  3.432373   62 -1.386294    0 -1.386294        6      0  0.371564     T
# ..  ..       ...       ...  ...       ...  ...       ...      ...    ...       ...   ...
# 92  93  2.830268  3.876396   68 -1.386294    1  1.321756        7     60  4.385147     T
# 93  94  3.821004  3.896909   44 -1.386294    1  2.169054        7     40  4.684443     T
# 94  95  2.907447  3.396185   52 -1.386294    1  2.463853        7     10  5.143124     F
# ...

# %%
# Splitting the dataset
X = data.drop(['id', 'lpsa', 'train'], axis=1)
y = data['lpsa']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Creating a model
model = RandomForestRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
print(f"MAE: {mae}")

mse = mean_squared_error(y_test, y_pred)
print(f"MSE: {mse}")

r2 = r2_score(y_test, y_pred)
print(f"R2 Score: {r2}")

#acc = accuracy_score(y_test, y_pred)
#print(f"Accuracy: {acc}")

#cr = classification_report(y_test, y_pred)
#print(f"Classification Report:\n {cr}")
# Out:
# MAE: 0.6624361125999998
# MSE: 0.6022735110952936
# R2 Score: 0.4447522198564008
